# %%
import numpy as np
import matplotlib.pyplot as plt
import ipympl
import imageio.v3 as iio
import skimage
import cv2 as cv

# %%
pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
img_1 = cv.imread("C:\\Users\ishuk\Desktop\sem 6\\lab\\digital image processing\\4\\dog.jpg")

# %%
plt.imshow(img_1)

# %%
plt.show(img_1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
img_11=cv.cvtColor(img_1, cv.COLOR_RGB2GRAY)

# %%
plt.imshow(img_11)

# %%
img_12=cv.equalizeHist(img_11)

# %%
plt.imshow(img_12)

# %%
plt.show(img_12)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
hist = cv.calcHist([img_12],[0],None,[256],[0,256])
plt.plot(hist)

# %%
plt.stem(hist)
# Out:
# <StemContainer object of 3 artists>

# %%
# find frequency of pixels in range 0-255
histr = cv.calcHist([img_12],[0],None,[256],[0,256])
  
# show the plotting graph of an image
plt.plot(histr)
plt.show(histr)
plt.imshow(histr)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.hist(img_12.ravel(),256,[0,256])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
