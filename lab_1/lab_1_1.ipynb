# %%
import skimage
import cv2
import numpy as np
import matplotlib.pyplot as plt
import ipympl
import imageio as iio

# %%
image = iio.imread(uri="C:\\Users\\ishuk\\Desktop\\sem 6\\lab\\digital image processing\\lab_1\\cat - Copy.jpg")
plt.imshow(image)

# %%
print(image.shape)
print(image.size)
# Out:
# (584, 612, 3)
# 1072224

# %%
#naming in image

plt.subplot(121) #sunplot(mnp) row ,coloum ,position

plt.grid('C:\\Users\\ishuk\\Desktop\\sem 6\\lab\\digital image processing\\lab_1\\cat.jpg')
plt.xlabel('ishu')
plt.ylabel('kumar')
plt.show(image)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
r_image = image[:, :, 0]
g_image = image[:, :, 1]
b_image = image[:, :, 2]

plt.subplot(221)
plt.show(r_image)

plt.subplot(222)
plt.show(g_image)

plt.subplot(223)
plt.show(b_image)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
gray1 = cv2.cvtColor(rgb, cv2.COLOR_RGB2GRAY)
plt.subplot(221)
plt.imshow(rgb)
plt.subplot(222)
plt.show(gray1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
image2 = iio.imread(uri="C:\\Users\\ishuk\\Desktop\\sem 6\\lab\\digital image processing\\lab_1\\cat.jpg")
plt.show(image2)
image1 = iio.imread(uri="C:\\Users\\ishuk\\Desktop\\sem 6\\lab\\digital image processing\\lab_1\\dog.jpg")
plt.imshow(image1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
